# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('/Data_Science/Kurs_project_task/train.csv')

# %%
data.head()
# Out:
#       Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0  14038          35    2.0  47.981561   29.442751            6.0      7
# 1  15053          41    3.0  65.683640   40.049543            8.0      7
# 2   4765          53    2.0  44.947953   29.197612            0.0      8
# 3   5809          58    2.0  53.352981   52.731512            9.0      8
# 4  10783          99    1.0  39.649192   23.776169            7.0     11
#
#    HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 0         9.0       1969   0.089040         B         B        33      7976
# 1         9.0       1978   0.000070         B         B        46     10309
# 2        12.0       1968   0.049637         B         B        34      7759
# 3        17.0       1977   0.437885         B         B        23      5735
# 4        12.0       1976   0.012339         B         B        35      5776
#
#    Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2          Price
# 0         5           NaN            0       11       B  184966.930730
# 1         1         240.0            1       16       B  300009.450063
# 2         0         229.0            1        3       B  220925.908524
# 3         3        1084.0            0        5       B  175616.227217
# 4         1        2078.0            2        4       B  150226.531644

# %%
data.shape
# Out:
# (10000, 20)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
# Id               10000 non-null int64
# DistrictId       10000 non-null int64
# Rooms            10000 non-null float64
# Square           10000 non-null float64
# LifeSquare       7887 non-null float64
# KitchenSquare    10000 non-null float64
# Floor            10000 non-null int64
# HouseFloor       10000 non-null float64
# HouseYear        10000 non-null int64
# Ecology_1        10000 non-null float64
# Ecology_2        10000 non-null object
# Ecology_3        10000 non-null object
# Social_1         10000 non-null int64
# Social_2         10000 non-null int64
# Social_3         10000 non-null int64
# Healthcare_1     5202 non-null float64
# Helthcare_2      10000 non-null int64
# Shops_1          10000 non-null int64
# Shops_2          10000 non-null object
# Price            10000 non-null float64
# dtypes: float64(8), int64(9), object(3)
# memory usage: 1.4+ MB

# %% [markdown]
# ##### Очистка HouseYear

# %%
data.loc[(data['HouseYear'] < 1900) | (data['HouseYear'] > 2020), :]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 1497  10814         109    1.0  37.265070   20.239714            9.0      9
# 4189  11607         147    2.0  44.791836   28.360393            5.0      4
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1497        12.0   20052011   0.136330         B         B        30
# 4189         9.0       4968   0.319809         B         B        25
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 1497      6141        10         262.0            3        6       B
# 4189      4756        16        2857.0            5        8       B
#
#               Price
# 1497  254084.534396
# 4189  243028.603096

# %%
data.loc[data['Id'] == 10814, 'HouseYear'] = 2011

# %%
#data.groupby(['DistrictId', 'HouseYear']).size()
#data.loc[(data['DistrictId'] == 147) & (data['HouseYear'] == 1968), :]
#data['Rooms'].value_counts()

# %%
data.loc[data['Id'] == 11607, 'HouseYear'] = 1968

# %%
data.loc[(data['HouseYear'] < 1900) | (data['HouseYear'] > 2020), :]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2, Price]
# Index: []

# %%
data['HouseYear'].value_counts().sort_index()
# Out:
# 1910      1
# 1912      2
# 1914      1
# 1916      1
# 1917      3
# 1918      5
# 1919      3
# 1928      1
# 1929      2
# 1930      3
# 1931      7
# 1932      2
# 1933      5
# 1934      4
# 1935      7
# 1936      3
# 1937      5
# 1938      4
# 1939      6
# 1940      4
# 1941      2
# 1942      3
# 1947      1
# 1948      2
# 1950      7
# 1951      4
# 1952     10
# 1953     10
# 1954     13
# 1955     20
#        ...
# 1991     68
# 1992     69
# 1993     47
# 1994     56
# 1995     68
# 1996     84
# 1997     65
# 1998     70
# 1999     82
# 2000     64
# 2001     62
# 2002     77
# 2003     89
# 2004     99
# 2005    102
# 2006     78
# 2007     95
# 2008     95
# 2009     96
# 2010     85
# 2011     92
# 2012     75
# 2013     95
# 2014    210
# 2015    299
# 2016    305
# 2017    308
# 2018    175
# 2019     79
# 2020     19
# Name: HouseYear, Length: 95, dtype: int64

# %% [markdown]
# ##### Очистка Floor и HouseFloor

# %%
data = data.astype({'HouseFloor' : int})

# %%
data['HouseFloor'].value_counts().sort_index()
# Out:
# 0       269
# 1       497
# 2        48
# 3       127
# 4       134
# 5      1031
# 6        58
# 7        59
# 8       141
# 9      1389
# 10      135
# 11       28
# 12     1074
# 13       27
# 14      625
# 15      123
# 16      576
# 17     2331
# 18       89
# 19      108
# 20      105
# 21       33
# 22      343
# 23       40
# 24      176
# 25      374
# 26        1
# 27        6
# 28        3
# 29        1
# 30       21
# 31        1
# 32        4
# 36        1
# 37        4
# 38        1
# 39        2
# 40        7
# 44        1
# 45        1
# 47        1
# 48        2
# 99        2
# 117       1
# Name: HouseFloor, dtype: int64

# %%
data.loc[(data['HouseFloor'] > 50), :]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 6131  10806           5    1.0  51.944587   48.709601            1.0      6
# 8599   9300          74    2.0  71.747869   74.579809            9.0      5
# 8854     78          30    2.0  65.773749   66.811789            1.0      8
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 6131          99       1977   0.150818         B         B        16
# 8599          99       1977   0.075779         B         B         6
# 8854         117       1977   0.000078         B         B        22
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 6131      3433         4        2643.0            4        5       B
# 8599      1437         3           NaN            0        2       B
# 8854      6398       141        1046.0            3       23       B
#
#               Price
# 6131  296127.115515
# 8599  243329.912579
# 8854  207248.370520

# %%
data.loc[data['HouseFloor'] == 99, 'HouseFloor'] = 9

# %%
data.loc[data['HouseFloor'] == 117, 'HouseFloor'] = 11

# %%
data.loc[(data['Floor'] > data['HouseFloor']), 'HouseFloor'] = data['Floor']

# %%
data['HouseFloor'].value_counts().sort_index()
# Out:
# 1       20
# 2       60
# 3      135
# 4      210
# 5      892
# 6      261
# 7      199
# 8      162
# 9     1286
# 10     294
# 11     132
# 12    1018
# 13     130
# 14     650
# 15     164
# 16     572
# 17    2247
# 18     204
# 19     169
# 20     118
# 21      49
# 22     342
# 23      39
# 24     186
# 25     382
# 26      17
# 27      11
# 28       4
# 29       1
# 30      21
# 31       1
# 32       4
# 36       1
# 37       4
# 38       1
# 39       2
# 40       7
# 44       1
# 45       1
# 47       1
# 48       2
# Name: HouseFloor, dtype: int64

# %%
data.loc[(data['Floor'] > data['HouseFloor']), :]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2, Price]
# Index: []

# %% [markdown]
# ##### Очистка Square

# %%
data.loc[(data['LifeSquare'] > data['Square']), 'Square'] = data['LifeSquare']

# %%
data.loc[(data['LifeSquare'] > data['Square']), :]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2, Price]
# Index: []

# %%
data.loc[data['Square'] < 20, :]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 1316  11526          27    1.0   4.633498    1.969969            1.0     18
# 1608  10202           6    1.0   4.604943    4.604943            1.0      3
# 1891  13685           0    1.0  17.498542   13.446544            0.0      7
# 3413   9487           5    1.0   5.549458    5.549458            1.0      1
# 3794    523         101    1.0  18.509177   15.170851            3.0      5
# 4739  12676          81    3.0  15.988889   15.988889            7.0      4
# 4853   3224          27    0.0   2.377248    0.873147            0.0      1
# 4900   4504          27    3.0   5.610772    5.610772            1.0      8
# 5617  15877          57    3.0  16.698571   16.698571            8.0      5
# 6392  14786           1    1.0   4.525736    4.525736            1.0      3
# 6945  12927          62    2.0  17.414181         NaN            1.0      4
# 7767   6927          21    1.0  16.117154    8.822988            0.0      2
# 7897  10635          21    1.0  18.983962   11.419796            2.0      1
# 8283  15744          34    1.0   2.642219    2.642219            1.0     21
# 9294   6782          45    1.0   5.257278    5.257278            1.0      3
# 9516  14236           0    1.0  19.927423   15.541536            0.0      2
# 9613   7657          38    1.0   4.618547    4.618547            1.0     28
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1316          18       1977   0.011654         B         B         4
# 1608          25       2014   0.243205         B         B         5
# 1891           7       1961   0.319809         B         B        25
# 3413           1       1977   0.150818         B         B        16
# 3794           5       1970   0.225825         A         B        41
# 4739           5       1960   0.319809         B         B        25
# 4853           1       1977   0.017647         B         B         2
# 4900          19       2016   0.211401         B         B         9
# 5617           5       1962   0.133215         B         B        49
# 6392           3       1977   0.007122         B         B         1
# 6945          20       1977   0.072158         B         B         2
# 7767           5       1965   0.194489         B         B        47
# 7897           5       1967   0.194489         B         B        47
# 8283          21       1977   0.069753         B         B        53
# 9294           3       1977   0.195781         B         B        23
# 9516           5       1962   0.319809         B         B        25
# 9613          28       1977   0.060753         B         B        15
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 1316       915         0           NaN            0        0       B
# 1608      1564         0         540.0            0        0       B
# 1891      4756        16        2857.0            5        8       B
# 3413      3433         4        2643.0            4        5       B
# 3794      6558         7        1548.0            3        2       B
# 4739      4756        16        2857.0            5        8       B
# 4853       469         0           NaN            0        0       B
# 4900      1892         0           NaN            0        1       B
# 5617     11395         3        1406.0            3        4       A
# 6392       264         0           NaN            0        1       B
# 6945       629         1           NaN            0        0       A
# 7767      8004         3         125.0            3        5       B
# 7897      8004         3         125.0            3        5       B
# 8283     13670         4           NaN            1       11       B
# 9294      5212         6           NaN            3        2       B
# 9516      4756        16        2857.0            5        8       B
# 9613      2787         2         520.0            0        7       B
#
#               Price
# 1316  107604.269441
# 1608  137597.601458
# 1891   88871.750230
# 3413  369472.403061
# 3794  115845.861527
# 4739   78388.806186
# 4853  126596.941798
# 4900  161379.067034
# 5617   77835.185808
# 6392  181434.825589
# 6945  180750.471749
# 7767   79913.267856
# 7897  112411.221700
# 8283  458378.777006
# 9294  438005.182323
# 9516  102395.788856
# 9613  483283.488083

# %% [markdown]
# ##### Очистка Rooms

# %%
data.loc[(data['Rooms'] > 3) & (data['Square'] < 60), :]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 377    5927          57   10.0  59.056975   36.223072           10.0     22
# 1454   8491           1   19.0  42.006046   21.779288            7.0     17
# 2170  14003          99    6.0  59.414334   38.702244            6.0      7
# 3271   6358          27    5.0  42.003293         NaN            0.0      5
# 4431   7594          53    5.0  39.906082   39.394024            1.0      5
# 8551  13772          96    4.0  44.128947   18.212628           10.0     10
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 377           22       2002   0.090799         B         B        74
# 1454          17       2014   0.007122         B         B         1
# 2170           9       1969   0.033494         B         B        66
# 3271          12       1977   0.011654         B         B         4
# 4431           5       1977   0.049637         B         B        34
# 8551          13       2005   0.041116         B         B        53
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 377      19083         2           NaN            5       15       B
# 1454       264         0           NaN            0        1       B
# 2170     10573         1        1322.0            3        8       B
# 3271       915         0           NaN            0        0       B
# 4431      7759         0         229.0            1        3       B
# 8551     14892         4           NaN            1        4       B
#
#               Price
# 377   317265.323792
# 1454   78364.616704
# 2170  229661.964416
# 3271  112693.641769
# 4431  206148.845716
# 8551  201374.604049

# %%
data.loc[(data['DistrictId'] == 57) & (data['HouseYear'] == 2002), :]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 377    5927          57   10.0  59.056975   36.223072           10.0     22
# 611    7690          57    1.0  38.912447   22.705071            7.0     18
# 1251  10639          57    1.0  39.947893   22.562042            8.0     18
# 3161  13636          57    2.0  61.979952   35.318691           10.0      3
# 9324  11235          57    2.0  59.613032   32.875040           12.0      4
# 9911  13841          57    2.0  63.034782   37.038307           10.0     14
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 377         22.0       2002   0.090799         B         B        74
# 611         17.0       2002   0.090799         B         B        74
# 1251        17.0       2002   0.133215         B         B        49
# 3161        17.0       2002   0.133215         B         B        49
# 9324        14.0       2002   0.133215         B         B        49
# 9911        17.0       2002   0.133215         B         B        49
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 377      19083         2           NaN            5       15       B
# 611      19083         2           NaN            5       15       B
# 1251     11395         3        1406.0            3        4       A
# 3161     11395         3        1406.0            3        4       A
# 9324     11395         3        1406.0            3        4       A
# 9911     11395         3        1406.0            3        4       A
#
#               Price
# 377   317265.323792
# 611   178934.843215
# 1251  172556.830900
# 3161  248095.790598
# 9324  270880.406751
# 9911  247601.262249
