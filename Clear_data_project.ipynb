# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('/Data_Science/Kurs_project_task/train.csv')

# %%
data.head()
# Out:
#       Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0  14038          35    2.0  47.981561   29.442751            6.0      7
# 1  15053          41    3.0  65.683640   40.049543            8.0      7
# 2   4765          53    2.0  44.947953   29.197612            0.0      8
# 3   5809          58    2.0  53.352981   52.731512            9.0      8
# 4  10783          99    1.0  39.649192   23.776169            7.0     11
#
#    HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 0         9.0       1969   0.089040         B         B        33      7976
# 1         9.0       1978   0.000070         B         B        46     10309
# 2        12.0       1968   0.049637         B         B        34      7759
# 3        17.0       1977   0.437885         B         B        23      5735
# 4        12.0       1976   0.012339         B         B        35      5776
#
#    Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2          Price
# 0         5           NaN            0       11       B  184966.930730
# 1         1         240.0            1       16       B  300009.450063
# 2         0         229.0            1        3       B  220925.908524
# 3         3        1084.0            0        5       B  175616.227217
# 4         1        2078.0            2        4       B  150226.531644

# %%
data.shape
# Out:
# (10000, 20)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
# Id               10000 non-null int64
# DistrictId       10000 non-null int64
# Rooms            10000 non-null float64
# Square           10000 non-null float64
# LifeSquare       7887 non-null float64
# KitchenSquare    10000 non-null float64
# Floor            10000 non-null int64
# HouseFloor       10000 non-null float64
# HouseYear        10000 non-null int64
# Ecology_1        10000 non-null float64
# Ecology_2        10000 non-null object
# Ecology_3        10000 non-null object
# Social_1         10000 non-null int64
# Social_2         10000 non-null int64
# Social_3         10000 non-null int64
# Healthcare_1     5202 non-null float64
# Helthcare_2      10000 non-null int64
# Shops_1          10000 non-null int64
# Shops_2          10000 non-null object
# Price            10000 non-null float64
# dtypes: float64(8), int64(9), object(3)
# memory usage: 1.4+ MB

# %%
data['Shops_2'].value_counts().sort_index()
# Out:
# A     825
# B    9175
# Name: Shops_2, dtype: int64

# %% [markdown]
# ##### Очистка HouseYear

# %%
data.loc[(data['HouseYear'] < 1900) | (data['HouseYear'] > 2020), :]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 1497  10814         109    1.0  37.265070   20.239714            9.0      9
# 4189  11607         147    2.0  44.791836   28.360393            5.0      4
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1497        12.0   20052011   0.136330         B         B        30
# 4189         9.0       4968   0.319809         B         B        25
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 1497      6141        10         262.0            3        6       B
# 4189      4756        16        2857.0            5        8       B
#
#               Price
# 1497  254084.534396
# 4189  243028.603096

# %%
data.loc[data['Id'] == 10814, 'HouseYear'] = 2011

# %%
#data.groupby(['DistrictId', 'HouseYear']).size()
#data.loc[(data['DistrictId'] == 147) & (data['HouseYear'] == 1968), :]
#data['Rooms'].value_counts()
#data.loc[data['DistrictId'] == 109, :].groupby(['HouseYear']).size()

# %%
data.loc[data['Id'] == 11607, 'HouseYear'] = 1968

# %%
data.loc[(data['HouseYear'] < 1900) | (data['HouseYear'] > 2020), :]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2, Price]
# Index: []

# %%
data['HouseYear'].value_counts().sort_index()
# Out:
# 1910      1
# 1912      2
# 1914      1
# 1916      1
# 1917      3
# 1918      5
# 1919      3
# 1928      1
# 1929      2
# 1930      3
# 1931      7
# 1932      2
# 1933      5
# 1934      4
# 1935      7
# 1936      3
# 1937      5
# 1938      4
# 1939      6
# 1940      4
# 1941      2
# 1942      3
# 1947      1
# 1948      2
# 1950      7
# 1951      4
# 1952     10
# 1953     10
# 1954     13
# 1955     20
#        ...
# 1991     68
# 1992     69
# 1993     47
# 1994     56
# 1995     68
# 1996     84
# 1997     65
# 1998     70
# 1999     82
# 2000     64
# 2001     62
# 2002     77
# 2003     89
# 2004     99
# 2005    102
# 2006     78
# 2007     95
# 2008     95
# 2009     96
# 2010     85
# 2011     92
# 2012     75
# 2013     95
# 2014    210
# 2015    299
# 2016    305
# 2017    308
# 2018    175
# 2019     79
# 2020     19
# Name: HouseYear, Length: 95, dtype: int64

# %% [markdown]
# ##### Очистка Floor и HouseFloor

# %%
data = data.astype({'HouseFloor' : int})

# %%
data['HouseFloor'].value_counts().sort_index()
# Out:
# 0       269
# 1       497
# 2        48
# 3       127
# 4       134
# 5      1031
# 6        58
# 7        59
# 8       141
# 9      1389
# 10      135
# 11       28
# 12     1074
# 13       27
# 14      625
# 15      123
# 16      576
# 17     2331
# 18       89
# 19      108
# 20      105
# 21       33
# 22      343
# 23       40
# 24      176
# 25      374
# 26        1
# 27        6
# 28        3
# 29        1
# 30       21
# 31        1
# 32        4
# 36        1
# 37        4
# 38        1
# 39        2
# 40        7
# 44        1
# 45        1
# 47        1
# 48        2
# 99        2
# 117       1
# Name: HouseFloor, dtype: int64

# %%
data.loc[(data['HouseFloor'] > 50), :]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 6131  10806           5    1.0  51.944587   48.709601            1.0      6
# 8599   9300          74    2.0  71.747869   74.579809            9.0      5
# 8854     78          30    2.0  65.773749   66.811789            1.0      8
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 6131          99       1977   0.150818         B         B        16
# 8599          99       1977   0.075779         B         B         6
# 8854         117       1977   0.000078         B         B        22
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 6131      3433         4        2643.0            4        5       B
# 8599      1437         3           NaN            0        2       B
# 8854      6398       141        1046.0            3       23       B
#
#               Price
# 6131  296127.115515
# 8599  243329.912579
# 8854  207248.370520

# %%
data.loc[data['HouseFloor'] == 99, 'HouseFloor'] = 9

# %%
data.loc[data['HouseFloor'] == 117, 'HouseFloor'] = 11

# %%
data.loc[(data['Floor'] > data['HouseFloor']), 'HouseFloor'] = data['Floor']

# %%
data['HouseFloor'].value_counts().sort_index()
# Out:
# 1       20
# 2       60
# 3      135
# 4      210
# 5      892
# 6      261
# 7      199
# 8      162
# 9     1286
# 10     294
# 11     132
# 12    1018
# 13     130
# 14     650
# 15     164
# 16     572
# 17    2247
# 18     204
# 19     169
# 20     118
# 21      49
# 22     342
# 23      39
# 24     186
# 25     382
# 26      17
# 27      11
# 28       4
# 29       1
# 30      21
# 31       1
# 32       4
# 36       1
# 37       4
# 38       1
# 39       2
# 40       7
# 44       1
# 45       1
# 47       1
# 48       2
# Name: HouseFloor, dtype: int64

# %%
data.loc[(data['Floor'] > data['HouseFloor']), :]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2, Price]
# Index: []

# %% [markdown]
# ##### Очистка Ecology_2 и Ecology_3 и Shops_2

# %%
data['Ecology_2'].value_counts().sort_index()
# Out:
# A      97
# B    9903
# Name: Ecology_2, dtype: int64

# %%
#data['Ecology_2'].replace({0: 'A', 1: 'B'}, inplace = False)
data.loc[data['Ecology_2'] == 'A', 'Ecology_2'] = 0
data.loc[data['Ecology_2'] == 'B', 'Ecology_2'] = 1

# %%
data['Ecology_3'].value_counts().sort_index()
# Out:
# A     275
# B    9725
# Name: Ecology_3, dtype: int64

# %%
data.loc[data['Ecology_3'] == 'A', 'Ecology_3'] = 0
data.loc[data['Ecology_3'] == 'B', 'Ecology_3'] = 1

# %%
data['Shops_2'].value_counts().sort_index()
# Out:
# A     825
# B    9175
# Name: Shops_2, dtype: int64

# %%
data.loc[data['Shops_2'] == 'A', 'Shops_2'] = 0
data.loc[data['Shops_2'] == 'B', 'Shops_2'] = 1

# %%
data.head()
# Out:
#       Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0  14038          35    2.0  47.981561   29.442751            6.0      7
# 1  15053          41    3.0  65.683640   40.049543            8.0      7
# 2   4765          53    2.0  44.947953   29.197612            0.0      8
# 3   5809          58    2.0  53.352981   52.731512            9.0      8
# 4  10783          99    1.0  39.649192   23.776169            7.0     11
#
#    HouseFloor  HouseYear  Ecology_1  Ecology_2  Ecology_3  Social_1  Social_2  \
# 0           9       1969   0.089040          1          1        33      7976
# 1           9       1978   0.000070          1          1        46     10309
# 2          12       1968   0.049637          1          1        34      7759
# 3          17       1977   0.437885          1          1        23      5735
# 4          12       1976   0.012339          1          1        35      5776
#
#    Social_3  Healthcare_1  Helthcare_2  Shops_1  Shops_2          Price
# 0         5           NaN            0       11        1  184966.930730
# 1         1         240.0            1       16        1  300009.450063
# 2         0         229.0            1        3        1  220925.908524
# 3         3        1084.0            0        5        1  175616.227217
# 4         1        2078.0            2        4        1  150226.531644

# %% [markdown]
# ##### Очистка Square

# %%
data.loc[(data['LifeSquare'] > data['Square']), 'Square'] = data['LifeSquare']

# %%
data.loc[(data['LifeSquare'] > data['Square']), :]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, LifeSquare, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2, Price]
# Index: []

# %%
data.loc[data['Square'] < 20, :].shape
# Out:
# (17, 20)

# %%
data.loc[data['Square'].between(150, 200), :]
# Out:
#          Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 652    3718          56    3.0  190.857689  107.376164           19.0      7
# 1641  11055         151    1.0  174.837082  174.837082           15.0     10
# 1812   5602          93    3.0  169.385184         NaN            1.0      2
# 2603   5621          23    3.0  163.495333  161.504222           12.0      5
# 2656  14556         183    4.0  151.150660   98.187482           23.0      6
# 3260  16204          23    1.0  160.647588         NaN            1.0      3
# 3368   6674          54    1.0  168.086347  125.486563           30.0     18
# 3651   5300          30    3.0  170.713651  170.713651            1.0      2
# 4047  15362          23    1.0  163.286965  161.155275            1.0      4
# 4487  13434          13    5.0  183.382273  100.985505           15.0      2
# 5087  15947         129    4.0  185.906396   84.830074           31.0      5
# 5444  14181          62    3.0  156.636577  153.685835            1.0      1
# 6201  10678          17    4.0  170.016872         NaN            0.0     12
# 6332   8961          27    1.0  164.153360  164.153360            6.0      3
# 6451   3914          24    4.0  155.930023   76.831293           15.0      6
# 7084   5376          93    2.0  170.379494         NaN            1.0      3
# 7201   3233         129    4.0  186.692602   87.487080           32.0      3
# 8131   4991          93    3.0  167.767027         NaN            1.0      1
# 8511   4249          23    5.0  198.930182  123.139863           10.0      1
# 8646  11764          93    3.0  169.117203         NaN            1.0      5
# 8913   2603          30    3.0  164.526757  164.526757            0.0      2
#
#       HouseFloor  HouseYear  Ecology_1  Ecology_2  Ecology_3  Social_1  \
# 652            7       2007   0.000000          1          1        23
# 1641          12       1958   0.236108          1          1        16
# 1812          10       1977   0.004949          1          1         0
# 2603           5       1977   0.014073          1          1         2
# 2656           7       1912   0.037316          1          1        32
# 3260           3       1977   0.014073          1          1         2
# 3368          28       2011   0.006076          1          1        30
# 3651           2       2018   0.000078          1          1        22
# 4047           4       1977   0.014073          1          1         2
# 4487           6       1997   0.090799          1          1        74
# 5087           5       2015   0.020741          1          1        24
# 5444           3       2005   0.072158          1          1         2
# 6201          12       1977   0.093443          1          1        23
# 6332           5       1965   0.211401          1          1         9
# 6451          22       2012   0.111627          1          1        50
# 7084           3       1977   0.004949          1          1         0
# 7201           3       2011   0.020741          1          1        24
# 8131           1       1977   0.004949          1          1         0
# 8511           2       2011   0.014073          1          1         2
# 8646           5       1977   0.004949          1          1         0
# 8913           3       1977   0.000078          1          1        22
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1  Shops_2  \
# 652       5067         4           NaN            2        6        1
# 1641      3893        27           NaN            3       10        1
# 1812       186         0           NaN            0        0        1
# 2603       475         0           NaN            0        0        1
# 2656      6748        93         562.0            4       10        1
# 3260       475         0           NaN            0        0        1
# 3368      5285         0         645.0            6        6        1
# 3651      6398       141        1046.0            3       23        1
# 4047       475         0           NaN            0        0        1
# 4487     19083         2           NaN            5       15        1
# 5087      5613         5        1340.0            2        5        1
# 5444       629         1           NaN            0        0        0
# 6201      4635         5        3300.0            2        4        1
# 6332      1892         0           NaN            0        1        1
# 6451     12238         8        1970.0            2        3        1
# 7084       186         0           NaN            0        0        1
# 7201      5613         5        1340.0            2        5        1
# 8131       186         0           NaN            0        0        1
# 8511       475         0           NaN            0        0        1
# 8646       186         0           NaN            0        0        1
# 8913      6398       141        1046.0            3       23        1
#
#               Price
# 652   338644.075979
# 1641  232766.187698
# 1812  190949.293998
# 2603  207007.956663
# 2656  284884.959104
# 3260  217874.997452
# 3368  367353.574566
# 3651  200800.673767
# 4047  228572.520347
# 4487  622888.825328
# 5087  340273.238253
# 5444  502523.573863
# 6201  531049.721966
# 6332  104891.073757
# 6451  559886.965348
# 7084  194582.912756
# 7201  423443.464367
# 8131  211180.794219
# 8511  345665.209100
# 8646  211325.577641
# 8913  207407.352593

# %% [markdown]
# ##### Очистка Rooms

# %%
data.loc[(data['Rooms'] > 3) & (data['Square'] < 60), :]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 377    5927          57   10.0  59.056975   36.223072           10.0     22
# 1454   8491           1   19.0  42.006046   21.779288            7.0     17
# 2170  14003          99    6.0  59.414334   38.702244            6.0      7
# 3271   6358          27    5.0  42.003293         NaN            0.0      5
# 4431   7594          53    5.0  39.906082   39.394024            1.0      5
# 8551  13772          96    4.0  44.128947   18.212628           10.0     10
#
#       HouseFloor  HouseYear  Ecology_1  Ecology_2  Ecology_3  Social_1  \
# 377           22       2002   0.090799          1          1        74
# 1454          17       2014   0.007122          1          1         1
# 2170           9       1969   0.033494          1          1        66
# 3271          12       1977   0.011654          1          1         4
# 4431           5       1977   0.049637          1          1        34
# 8551          13       2005   0.041116          1          1        53
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1  Shops_2  \
# 377      19083         2           NaN            5       15        1
# 1454       264         0           NaN            0        1        1
# 2170     10573         1        1322.0            3        8        1
# 3271       915         0           NaN            0        0        1
# 4431      7759         0         229.0            1        3        1
# 8551     14892         4           NaN            1        4        1
#
#               Price
# 377   317265.323792
# 1454   78364.616704
# 2170  229661.964416
# 3271  112693.641769
# 4431  206148.845716
# 8551  201374.604049

# %%
data.loc[(data['DistrictId'] == 57) & (data['HouseYear'] == 2002), :]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 377    5927          57   10.0  59.056975   36.223072           10.0     22
# 611    7690          57    1.0  38.912447   22.705071            7.0     18
# 1251  10639          57    1.0  39.947893   22.562042            8.0     18
# 3161  13636          57    2.0  61.979952   35.318691           10.0      3
# 9324  11235          57    2.0  59.613032   32.875040           12.0      4
# 9911  13841          57    2.0  63.034782   37.038307           10.0     14
#
#       HouseFloor  HouseYear  Ecology_1  Ecology_2  Ecology_3  Social_1  \
# 377           22       2002   0.090799          1          1        74
# 611           18       2002   0.090799          1          1        74
# 1251          18       2002   0.133215          1          1        49
# 3161          17       2002   0.133215          1          1        49
# 9324          14       2002   0.133215          1          1        49
# 9911          17       2002   0.133215          1          1        49
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1  Shops_2  \
# 377      19083         2           NaN            5       15        1
# 611      19083         2           NaN            5       15        1
# 1251     11395         3        1406.0            3        4        0
# 3161     11395         3        1406.0            3        4        0
# 9324     11395         3        1406.0            3        4        0
# 9911     11395         3        1406.0            3        4        0
#
#               Price
# 377   317265.323792
# 611   178934.843215
# 1251  172556.830900
# 3161  248095.790598
# 9324  270880.406751
# 9911  247601.262249
